# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Health-fw-stat-2015_A11.csv")

# %%
df = df.drop(columns=["Sl.No."])

# %%
df.head()
# Out:
#   Sl.No.         States/Uts   0-4  `5-9  `10-14  15-19  20-24  25-29  30-34  \
# 0  India              India   9.3  10.5    11.0   10.0    9.2    8.4    7.3
# 1      1     Andhra Pradesh   7.4   8.6     9.7    9.6    9.6    9.2    7.8
# 2      2  Arunachal Pradesh  10.3  12.4    13.0   11.3    9.5    8.9    7.3
# 3      3              Assam  10.3  11.4    11.2    9.8    9.3    9.0    7.5
# 4      4              Bihar  12.3  14.4    13.4    9.1    7.7    7.4    6.8
#
#    35-39  ...  60-64  65-69  70-74  75-79  80-84  85-89  90-94  95-99  100+  \
# 0    7.0  ...    3.1    2.2    1.6    0.8    0.5    0.2    0.1    0.1   0.1
# 1    7.7  ...    3.8    2.6    1.8    0.8    0.5    0.2    0.1    0.0   0.0
# 2    6.8  ...    1.8    1.1    0.8    0.4    0.3    0.1    0.1    0.0   0.0
# 3    7.2  ...    2.5    1.6    1.2    0.6    0.4    0.1    0.1    0.1   0.0
# 4    6.2  ...    2.9    2.0    1.3    0.5    0.4    0.1    0.1    0.0   0.0
#
#    Age not stated
# 0             0.4
# ...

# %%
df.head()
# Out:
#           States/Uts   0-4  `5-9  `10-14  15-19  20-24  25-29  30-34  35-39  \
# 0              India   9.3  10.5    11.0   10.0    9.2    8.4    7.3    7.0
# 1     Andhra Pradesh   7.4   8.6     9.7    9.6    9.6    9.2    7.8    7.7
# 2  Arunachal Pradesh  10.3  12.4    13.0   11.3    9.5    8.9    7.3    6.8
# 3              Assam  10.3  11.4    11.2    9.8    9.3    9.0    7.5    7.2
# 4              Bihar  12.3  14.4    13.4    9.1    7.7    7.4    6.8    6.2
#
#    40-44  ...  60-64  65-69  70-74  75-79  80-84  85-89  90-94  95-99  100+  \
# 0    6.0  ...    3.1    2.2    1.6    0.8    0.5    0.2    0.1    0.1   0.1
# 1    6.4  ...    3.8    2.6    1.8    0.8    0.5    0.2    0.1    0.0   0.0
# 2    5.7  ...    1.8    1.1    0.8    0.4    0.3    0.1    0.1    0.0   0.0
# 3    5.9  ...    2.5    1.6    1.2    0.6    0.4    0.1    0.1    0.1   0.0
# 4    5.0  ...    2.9    2.0    1.3    0.5    0.4    0.1    0.1    0.0   0.0
#
#    Age not stated
# 0             0.4
# ...

# %%
print(df.columns)
# Out:
# Index(['States/Uts', '0-4', '`5-9', '`10-14', '15-19', '20-24', '25-29',
#        '30-34', '35-39', '40-44', '45-49', '50-54', '55-59', '60-64', '65-69',
#        '70-74', '75-79', '80-84', '85-89', '90-94', '95-99', '100+',
#        'Age not stated'],
#       dtype='object')

# %%
india = df[df["States/Uts"] == "India"].iloc[0, 1:]  # skip "States/Uts"

india.plot(kind="bar", figsize=(12,6))
plt.title("Population by Age Group in India")
plt.xlabel("Age Group")
plt.ylabel("Population")
plt.show()

# %%
state = "Uttar Pradesh"
row = df[df["States/Uts"] == state].iloc[0, 1:]   # all columns except 'States/Uts'

row.plot(kind="bar", figsize=(12,6))
plt.title(f"Population by Age Group in {state}")
plt.xlabel("Age Group")
plt.ylabel("Population")
plt.show()

# %%
import matplotlib.pyplot as plt

state = "Karnataka"
row = df[df["States/Uts"] == state].iloc[0, 1:]   # all columns except 'States/Uts'

row.plot(kind="bar", figsize=(12,6))
plt.title(f"Population by Age Group in {state}")
plt.xlabel("Age Group")
plt.ylabel("Population")
plt.show()

# %%
states = ["India", "Uttar Pradesh", "Kerala", "Tamil Nadu"]
subset = df[df["States/Uts"].isin(states)].set_index("States/Uts")

subset.T.plot(kind="bar", figsize=(14,7))
plt.title("Age Distribution: India vs Selected States")
plt.xlabel("Age Group")
plt.ylabel("Population")
plt.legend(title="Region")
plt.show()

# %%
import seaborn as sns

plt.figure(figsize=(14,8))
sns.heatmap(df.set_index("States/Uts"), cmap="viridis")
plt.title("Population Heatmap by Age Group (India & States/UTs)")
plt.show()

# %% [markdown]
# Market segmentation for age distribution is done in this file
